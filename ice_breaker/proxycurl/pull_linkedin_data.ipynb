# %% [markdown]
# # <font color='yellow' face="Rockwell" size="6">Pull Linkedin data</font>

# %%
import requests
import os
import json
from dotenv import dotenv_values
config = dotenv_values(".env")
PROXYCURL_API_KEY = config["PROXYCURL_API_KEY"]

# %%
# headers = {'Authorization': 'Bearer ' + PROXYCURL_API_KEY}
# api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
# params = {
#     'linkedin_profile_url': 'https://www.linkedin.com/in/siddharthmaity/'
# }
# response = requests.get(api_endpoint,
#                         params=params,
#                         headers=headers)

# data = response.json()
# print(data)

# # Saving the JSON data to a file
# with open('linkedin_data.json', 'w') as file:
#     json.dump(data, file, indent=4)

# %%
with open('linkedin_data.json', 'r') as file:
    data = json.load(file)
print(data)
# Out:
# {'public_identifier': 'siddharthmaity', 'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/siddharthmaity/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240427%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240427T194520Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=9e0a475d03c61f8411e1fbe08a926347d0ede0d2a7048c5be2b1b588ee8a4d9f', 'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/siddharthmaity/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240427%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240427T194520Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=72f81c653e96e3f96f2fc575345ba96243c7947a72e57e39824f11a206c67526', 'first_name': 'Siddharth', 'last_name': 'Maity', 'full_name': 'Siddharth Maity', 'follower_count': None, 'occupation': 'Data Intelligence Manager at CafeMedia', 'headline': 'Data Intelligence - CafeM
# ...

# %%
gist_response = requests.get("https://gist.githubusercontent.com/maitys/f76b2ecf798087b0abf8c6fea9f68b19/raw/6beeda020d0aa690f2c0873a35ba3a50bed8202f/siddharth-maity-linkedin-json")
gist_response.json()
# Out:
# {'public_identifier': 'siddharthmaity',
#  'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/siddharthmaity/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240427%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240427T194520Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=9e0a475d03c61f8411e1fbe08a926347d0ede0d2a7048c5be2b1b588ee8a4d9f',
#  'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/siddharthmaity/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240427%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240427T194520Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=72f81c653e96e3f96f2fc575345ba96243c7947a72e57e39824f11a206c67526',
#  'first_name': 'Siddharth',
#  'last_name': 'Maity',
#  'full_name': 'Siddharth Maity',
#  'follower_count': None,
#  'occupation': 'Data Intelligence Manager at CafeMedia',
# ...
